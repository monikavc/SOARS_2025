# %%
# plotting
import matplotlib.pyplot as plt

# calculating/regridding
import xarray as xr                        
import numpy as np 
import pandas as pd
import xesmf as xe
from scipy.stats import linregress

# %%
omi_mls_ds = xr.open_dataarray("/glade/u/home/mvoncyga/SOARS_2025/300hpa_full_monthly_omimls_tco.nc")
omi_mls_ds = omi_mls_ds.rename({'latitude': 'lat', 'longitude': 'lon'})

# shifting lon to be 0-360
omi_mls_ds['lon'] = omi_mls_ds['lon'] % 360
omi_mls_ds = omi_mls_ds.sortby('lon')

# %%
cesm_output = xr.open_dataarray("/glade/u/home/mvoncyga/SOARS_2025/300hPa_tco_monthly.nc")

# %%
regridder = xe.Regridder(cesm_output, omi_mls_ds, 'bilinear', periodic=True) 
cesm_regridded = regridder(cesm_output)

# %%
global_cesm_data = cesm_regridded.mean(dim={'lat','lon'})
#global_cesm_data
# Out:
# <xarray.DataArray (time: 240)> Size: 960B
# array([20.406069, 21.11295 , 22.026075, 22.983515, 22.794619, 22.179787,
#        22.32113 , 22.223501, 21.891792, 21.073181, 20.466406, 20.5095  ,
#        21.142221, 21.932306, 23.119139, 23.735128, 23.54947 , 22.814512,
#        22.4319  , 22.206285, 21.575302, 20.929424, 20.015554, 19.593634,
#        19.97429 , 20.59526 , 21.821236, 22.459892, 22.478195, 22.25268 ,
#        22.190992, 22.170204, 21.997137, 21.24952 , 20.59603 , 20.036444,
#        20.368711, 21.715233, 23.067408, 23.925743, 23.404919, 22.6041  ,
#        22.533327, 22.226513, 21.84189 , 20.914455, 20.111889, 19.80583 ,
#        20.46821 , 21.896767, 23.048546, 23.283789, 22.700926, 21.902893,
#        21.757399, 21.41235 , 20.769682, 20.191328, 20.016733, 20.036692,
#        20.845362, 21.659449, 22.608873, 23.404116, 23.113693, 21.983112,
#        22.21605 , 22.847387, 22.629757, 21.592667, 20.617947, 20.402473,
#        21.110617, 21.681175, 22.683603, 23.299753, 23.147423, 22.4748  ,
#        22.283731, 22.09325 , 21.974903, 21.015821, 20.403545, 19.920246,
#        20.05872 , 21.206715, 22.86106 , 24.081362, 23.968143, 22.896643,
#        22.283104, 22.380505, 22.284718, 21.238636, 20.566319, 20.646606,
#        21.382723, 22.017197, 22.962824, 23.671553, 23.377007, 23.019123,
#        22.607576, 22.575111, 22.211605, 21.328514, 20.519714, 20.820776,
#        20.702324, 21.026354, 21.907206, 22.772879, 23.193415, 22.090229,
#        22.043695, 22.14233 , 21.866455, 21.14648 , 20.571718, 20.483078,
# ...
#        22.136232, 21.906569, 21.301916, 20.552736, 19.846481, 19.788511,
#        20.146702, 20.733982, 21.730602, 22.796307, 22.802624, 21.975727,
#        22.101007, 22.139593, 21.486185, 21.371016, 20.745737, 20.840242,
#        21.458197, 22.492256, 23.52478 , 23.996407, 23.458372, 22.40463 ,
#        22.414745, 22.471775, 22.223692, 21.82765 , 21.028423, 21.078289,
#        21.461588, 22.218029, 23.380825, 24.386238, 24.27309 , 23.37629 ,
#        22.702356, 22.517574, 22.320082, 21.367847, 20.761854, 20.762129,
#        21.319605, 22.226166, 22.845644, 23.781708, 23.698233, 23.002943,
#        22.587961, 22.79221 , 22.373587, 21.77191 , 21.316412, 21.319498,
#        21.59303 , 22.021551, 22.628414, 23.447191, 23.34004 , 22.80502 ,
#        23.06256 , 23.028986, 22.788164, 21.974573, 21.187769, 20.991837,
#        21.575665, 22.404375, 23.1417  , 23.649366, 23.535679, 22.8426  ,
#        22.89711 , 23.175385, 22.724337, 22.106813, 21.302551, 21.055605,
#        21.467045, 22.298967, 22.945633, 24.078585, 23.941544, 23.13334 ,
#        23.234653, 23.022593, 22.961412, 21.95004 , 21.229986, 21.123905,
#        21.579952, 22.616821, 23.660746, 24.685932, 24.613955, 23.600586,
#        23.119072, 22.913765, 22.276243, 21.678501, 21.079266, 20.90405 ,
#        21.22057 , 22.643223, 23.769953, 24.945276, 25.150229, 24.60255 ,
#        23.413313, 22.855303, 22.349127, 22.26404 , 21.586477, 21.330496],
#       dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 2kB 2005-02-01 2005-03-01 ... 2025-01-01

# %%
cesm_dates = global_cesm_data.coords['time']
num_cesm_dates = np.arange(0, len(cesm_dates), 1)

# %%
cesm_slope, cesm_intercept, r_value_cesm, p_value, std_err = linregress(num_cesm_dates, global_cesm_data)
cesm_lin_reg = cesm_slope * num_cesm_dates + cesm_intercept
r_squared_cesm = r_value_cesm**2

# %%
def timeseries_plot(dates, dataset, linreg, title, r_squared, slope, intercept):
    plt.figure(figsize=(10,6))
    ax = plt.axes()

    plt.plot(dates, dataset, linewidth=2, color='#5acc0e')
    plt.plot(dates, linreg, color='black', linestyle='dashdot', linewidth=1.5)

    plt.grid(True, linestyle='--', alpha=0.7)

    ax.text(0.9, 0.08, '$R^2=$' + f"{r_squared:.3f}", horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, fontsize=15)
    ax.text(0.81, 0.03, f'y = {slope:.2f}x + {intercept:.2f}' + " DU/month", horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, fontsize=15)
    
    plt.title(title, fontsize=19)
    plt.ylabel("$\mathregular{O_3}$ Concentration (DU)", fontsize=15)
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
timeseries_plot(cesm_dates, global_cesm_data, cesm_lin_reg, "CESM Annual 300hPa TCO", r_squared_cesm, cesm_slope, cesm_intercept)

# %%
global_omi_mls_data = omi_mls_ds.mean(dim={'lat','lon'})
#global_omi_mls_data

# %%
omi_mls_dates = omi_mls_ds.coords['yearmonth']
num_omi_mls_dates = np.arange(0, len(omi_mls_dates), 1)

# %%
omi_mls_slope, omi_mls_intercept, r_value_omi_mls, p_value, std_err = linregress(num_omi_mls_dates, global_omi_mls_data)
omi_mls_lin_reg = omi_mls_slope * num_omi_mls_dates + omi_mls_intercept
r_squared_omi_mls = r_value_omi_mls**2

# %%
timeseries_plot(omi_mls_dates, global_omi_mls_data, omi_mls_lin_reg, "OMI/MLS Annual 300hPa TCO", r_squared_omi_mls, omi_mls_slope, omi_mls_intercept)

# %%
global_omi_mls_data = global_omi_mls_data.rename({"yearmonth": "time"})
difference = global_cesm_data - global_omi_mls_data

# %%
print(difference)
# Out:
# <xarray.DataArray (time: 239)> Size: 956B
# array([ 1.0973358e-01, -6.3409424e-01, -1.2583389e+00, -1.1327114e+00,
#        -1.3889313e+00, -1.9386330e+00, -1.4094734e+00, -9.4726753e-01,
#        -1.5149918e+00, -8.5113335e-01, -2.3980331e-01,  9.6207619e-01,
#         8.7269020e-01, -1.0769272e-01,  2.1129417e-01, -7.0419121e-01,
#        -5.0928116e-01, -9.3088150e-01, -7.2446823e-01, -7.1636200e-01,
#        -9.2661285e-01, -3.7066650e-01,  1.9601059e-01,  4.0668678e-01,
