# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs               
import cartopy.feature as cfeature         
import cartopy.util as cutil
import xarray as xr                        
import numpy as np
import pandas as pd
import plotting_module
import xesmf as xe

# %%
ozone_dataset = xr.open_dataset("/glade/campaign/acom/acom-climate/UTLS/shawnh/archive/FCnudged_f09.mam.mar27.2000_2021.002/atm/proc/tseries/month_1/FCnudged_f09.mam.mar27.2000_2021.002.cam.h0.O3.200201-202412.nc")
pdeldry_dataset = xr.open_dataset("/glade/campaign/acom/acom-climate/UTLS/shawnh/archive/FCnudged_f09.mam.mar27.2000_2021.002/atm/proc/tseries/month_1/FCnudged_f09.mam.mar27.2000_2021.002.cam.h0.PDELDRY.200201-202412.nc")
ps_dataset = xr.open_dataset('/glade/campaign/acom/acom-climate/UTLS/shawnh/archive/FCnudged_f09.mam.mar27.2000_2021.002/atm/proc/tseries/month_1/FCnudged_f09.mam.mar27.2000_2021.002.cam.h0.PS.200201-202412.nc')

# %%
ozone = ozone_dataset["O3"]

# %%
p0 = ozone_dataset["P0"]
hyai = ozone_dataset["hyai"]
hybi = ozone_dataset["hybi"]
ps = ps_dataset['PS']
pdeldry = pdeldry_dataset['PDELDRY']
lev = ozone_dataset.coords['lev']
num_lev = lev.shape[0]

# convert to hPa from Pa
p0 = p0.copy() / 100
ps = ps.copy() / 100
pdeldry = pdeldry.copy() / 100 

# truncate to levels 16-31
truncated_pdeldry = pdeldry.isel({pdeldry.dims[1]: slice(17, 31)})
truncated_ozone = ozone.isel({ozone.dims[1]: slice(17, 31)})

# %%
ps
# Out:
# <xarray.DataArray 'PS' (time: 276, lat: 192, lon: 288)> Size: 61MB
# array([[[ 684.48846,  684.48846,  684.48846, ...,  684.48846,
#           684.48846,  684.48846],
#         [ 695.9178 ,  695.636  ,  695.3219 , ...,  696.7668 ,
#           696.4867 ,  696.1936 ],
#         [ 703.711  ,  703.11255,  702.49713, ...,  705.4769 ,
#           704.89343,  704.3017 ],
#         ...,
#         [1010.50604, 1010.4881 , 1010.4715 , ..., 1010.5642 ,
#          1010.544  , 1010.52454],
#         [1011.76807, 1011.7605 , 1011.75305, ..., 1011.79315,
#          1011.7844 , 1011.7762 ],
#         [1012.7434 , 1012.7434 , 1012.7434 , ..., 1012.7434 ,
#          1012.7434 , 1012.7434 ]],
#
#        [[ 678.2912 ,  678.2912 ,  678.2912 , ...,  678.2912 ,
#           678.2912 ,  678.2912 ],
#         [ 689.99396,  689.7057 ,  689.3845 , ...,  690.8591 ,
#           690.57416,  690.2756 ],
#         [ 697.76544,  697.154  ,  696.52576, ...,  699.5708 ,
#           698.9743 ,  698.3693 ],
# ...
#         [1004.4788 , 1004.4471 , 1004.4151 , ..., 1004.576  ,
#          1004.5444 , 1004.5121 ],
#         [1004.9451 , 1004.9243 , 1004.9034 , ..., 1005.00616,
#          1004.9863 , 1004.96594],
#         [1005.0248 , 1005.0248 , 1005.0248 , ..., 1005.0248 ,
#          1005.0248 , 1005.0248 ]],
#
#        [[ 681.7545 ,  681.7545 ,  681.7545 , ...,  681.7545 ,
#           681.7545 ,  681.7545 ],
#         [ 693.32544,  693.0361 ,  692.7139 , ...,  694.1957 ,
#           693.9087 ,  693.60834],
#         [ 701.11163,  700.4997 ,  699.87103, ...,  702.9197 ,
#           702.3223 ,  701.71655],
#         ...,
#         [1011.6014 , 1011.60724, 1011.61475, ..., 1011.58624,
#          1011.5906 , 1011.59576],
#         [1012.9016 , 1012.90204, 1012.9026 , ..., 1012.9037 ,
#          1012.90216, 1012.9016 ],
#         [1013.9791 , 1013.9791 , 1013.9791 , ..., 1013.9791 ,
#          1013.9791 , 1013.9791 ]]], dtype=float32)
# Coordinates:
#   * lat      (lat) float64 2kB -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon      (lon) float64 2kB 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * time     (time) datetime64[ns] 2kB 2002-02-01 2002-03-01 ... 2025-01-01

# %% [markdown]
# Now group 'ozone' and 'pdeldry' DataArrays by months

# %%
start_date = '2005-02-01'
end_date = '2025-01-01'

# group the 240 month dates based on calendar months for both PDELDRY and O3 variables

truncated_pdeldry = truncated_pdeldry.sel(time=slice(start_date, end_date))
pdeldry_monthly_mean = truncated_pdeldry.groupby('time.month').mean('time')
pdeldry_monthly_mean = pdeldry_monthly_mean.transpose('lev','month','lat','lon')

truncated_ozone = truncated_ozone.sel(time=slice(start_date, end_date))
ozone_monthly_mean = truncated_ozone.groupby('time.month').mean('time')
ozone_monthly_mean = ozone_monthly_mean.transpose('lev','month','lat','lon')

# %%
# constants / conversion factor
NAv = 6.0221415e+23                       # molecules in mole
g = 9.81                                  # gravity
MWair = 28.94                             # g/mol
xp_const = (NAv * 10)/(MWair*g)           # scaling factor, pa to hPa and cm to m
DU_CONVERSION = 2.69 * 10**16

# %%
# Initialize pressure edge arrays
#mod_press_low = xr.zeros_like(ozone).transpose('lev','lat','lon','time')
mod_press_top = xr.zeros_like(ozone).transpose('lev','lat','lon','time')

# %% [markdown]
# Calculating pressure at hybrid levels
#
# p(k) = a(k) * p0 + b(k) * ps

# %%
# Calculate pressure edge arrays
# CAM-chem layer indices start at the top and end at the bottom
for i in range(num_lev):
    mod_press_top[i,:,:,:] = hyai[i]*p0 + hybi[i]*ps

# %%
mod_press_top = mod_press_top.transpose('lev', 'time', 'lat', 'lon')

# %%
filtered_300hpa_upper = mod_press_top.where(mod_press_top >= 300, drop=False)

# %%
filtered_300hpa_upper[17].min()
# Out:
# <xarray.DataArray 'O3' ()> Size: 8B
# array(300.)
# Coordinates:
#     lev      float64 8B 322.2

# %%
filtered_300hpa_upper[19].min()
# Out:
# <xarray.DataArray 'O3' ()> Size: 8B
# array(300.)
# Coordinates:
#     lev      float64 8B 446.0

# %%
filtered_300hpa_upper[19].isnull().sum() / filtered_300hpa_upper[19].size
# Out:
# <xarray.DataArray 'O3' ()> Size: 8B
# array(0.00537136)
# Coordinates:
#     lev      float64 8B 446.0

# %%
mod_deltap = abs(300 - filtered_300hpa_upper)
mod_deltap
# Out:
# <xarray.DataArray 'O3' (lev: 32, time: 276, lat: 192, lon: 288)> Size: 2GB
# array([[[[      nan,       nan,       nan, ...,       nan,       nan,
#                 nan],
#          [      nan,       nan,       nan, ...,       nan,       nan,
#                 nan],
#          [      nan,       nan,       nan, ...,       nan,       nan,
#                 nan],
#          ...,
#          [      nan,       nan,       nan, ...,       nan,       nan,
#                 nan],
#          [      nan,       nan,       nan, ...,       nan,       nan,
#                 nan],
#          [      nan,       nan,       nan, ...,       nan,       nan,
#                 nan]],
#
#         [[      nan,       nan,       nan, ...,       nan,       nan,
#                 nan],
#          [      nan,       nan,       nan, ...,       nan,       nan,
#                 nan],
#          [      nan,       nan,       nan, ...,       nan,       nan,
#                 nan],
# ...
#          [689.52435, 689.49304, 689.46155, ..., 689.62006, 689.5889 ,
#           689.5571 ],
#          [689.9837 , 689.9632 , 689.94257, ..., 690.0438 , 690.0243 ,
#           690.0042 ],
#          [690.06213, 690.06213, 690.06213, ..., 690.06213, 690.06213,
#           690.06213]],
#
#         [[371.60468, 371.60468, 371.60468, ..., 371.60468, 371.60468,
#           371.60468],
#          [383.00336, 382.71826, 382.40094, ..., 383.8606 , 383.57788,
#           383.28204],
#          [390.67365, 390.0708 , 389.45148, ..., 392.45477, 391.86627,
#           391.26953],
#          ...,
#          [696.54083, 696.54663, 696.554  , ..., 696.52594, 696.5302 ,
#           696.53534],
#          [697.8217 , 697.82214, 697.8227 , ..., 697.8238 , 697.82227,
#           697.8217 ],
#          [698.8832 , 698.8832 , 698.8832 , ..., 698.8832 , 698.8832 ,
#           698.8832 ]]]], dtype=float32)
# Coordinates:
#   * lat      (lat) float64 2kB -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon      (lon) float64 2kB 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * lev      (lev) float64 256B 3.643 7.595 14.36 24.61 ... 957.5 976.3 992.6
#   * time     (time) datetime64[ns] 2kB 2002-02-01 2002-03-01 ... 2025-01-01

# %%
ozone_filtered = ozone.where(mod_deltap.notnull())
ozone_filtered = ozone_filtered.transpose('lev','time','lat','lon')

# %%
mod_deltap_filtered = mod_deltap.where(ozone_filtered.notnull())

# %%
# check if data array is all NaN
mod_deltap_filtered.mean(dim={'lev', 'time','lat','lon'}, skipna=True)
# Out:
# <xarray.DataArray 'O3' ()> Size: 4B
# array(423.76816, dtype=float32)

# %%
mod_deltap_filtered = mod_deltap_filtered.fillna(0)
ozone_filtered = ozone_filtered.fillna(0)

# %%
mod_deltap_filtered = mod_deltap_filtered.sel(time=slice(start_date, end_date))
ozone_filtered = ozone_filtered.sel(time=slice(start_date, end_date))

mod_deltap_filtered = mod_deltap_filtered.groupby('time.month').mean('time')
ozone_filtered = ozone_filtered.groupby('time.month').mean('time')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 5
#       2 ozone_filtered = ozone_filtered.sel(time=slice(start_date, end_date))
#       4 mod_deltap_filtered = mod_deltap_filtered.groupby('time.month').mean('time')
# ----> 5 ozone_filtered = ozone_filtered.groupby('time.month').mean('time')
#
# File /glade/u/apps/opt/conda/envs/npl-2025a/lib/python3.12/site-packages/xarray/core/_aggregations.py:7229, in DataArrayGroupByAggregations.mean(self, dim, skipna, keep_attrs, **kwargs)
#    7147 """
#    7148 Reduce this DataArray's data by applying ``mean`` along some dimension(s).
#    7149
#    (...)
#    7222   * labels   (labels) object 24B 'a' 'b' 'c'
#    7223 """
#    7224 if (
#    7225     flox_available
#    7226     and OPTIONS["use_flox"]
#    7227     and contains_only_chunked_or_numpy(self._obj)
#    7228 ):
# -> 7229     return self._flox_reduce(
#    7230         func="mean",
#    7231         dim=dim,
#    7232         skipna=skipna,
#    7233         # fill_value=fill_value,
#    7234         keep_attrs=keep_attrs,
#    7235         **kwargs,
#    7236     )
#    7237 else:
#    7238     return self.reduce(
#    7239         duck_array_ops.mean,
#    7240         dim=dim,
#    (...)
#    7243         **kwargs,
#    7244     )
#
# File /glade/u/apps/opt/conda/envs/npl-2025a/lib/python3.12/site-packages/xarray/core/groupby.py:1093, in GroupBy._flox_reduce(self, dim, keep_attrs, **kwargs)
#    1088 expected_groups = tuple(
#    1089     pd.RangeIndex(len(grouper)) for grouper in self.groupers
#    1090 )
#    1092 codes = tuple(g.codes for g in self.groupers)
# -> 1093 result = xarray_reduce(
#    1094     obj.drop_vars(non_numeric.keys()),
#    1095     *codes,
#    1096     dim=parsed_dim,
#    1097     expected_groups=expected_groups,
#    1098     isbin=False,
#    1099     keep_attrs=keep_attrs,
#    1100     **kwargs,
#    1101 )
#    1103 # we did end up reducing over dimension(s) that are
#    1104 # in the grouped variable
#    1105 group_dims = set(grouper.group.dims)
#
# File /glade/u/apps/opt/conda/envs/npl-2025a/lib/python3.12/site-packages/flox/xarray.py:435, in xarray_reduce(obj, func, expected_groups, isbin, sort, dim, fill_value, dtype, method, engine, keep_attrs, skipna, min_count, reindex, *by, **finalize_kwargs)
#     432 output_sizes = group_sizes
#     433 output_sizes.update({dim.name: dim.size for dim in newdims if dim.size != 0})
# --> 435 actual = xr.apply_ufunc(
#     436     wrapper,
#     437     ds_broad.drop_vars(tuple(missing_dim)).transpose(..., *grouper_dims),
#     438     *by_da,
#     439     input_core_dims=input_core_dims,
#     440     # for xarray's test_groupby_duplicate_coordinate_labels
#     441     exclude_dims=set(dim_tuple),
#     442     output_core_dims=[output_core_dims],
#     443     dask="allowed",
#     444     dask_gufunc_kwargs=dict(
#     445         output_sizes=output_sizes,
#     446         output_dtypes=[dtype] if dtype is not None else None,
#     447     ),
#     448     keep_attrs=keep_attrs,
#     449     kwargs={
#     450         "func": func,
#     451         "axis": axis,
#     452         "sort": sort,
#     453         "fill_value": fill_value,
#     454         "method": method,
#     455         "min_count": min_count,
#     456         "skipna": skipna,
#     457         "engine": engine,
#     458         "reindex": reindex,
#     459         "expected_groups": tuple(expected_groups_valid_list),
#     460         "isbin": isbins,
#     461         "finalize_kwargs": finalize_kwargs,
#     462         "dtype": dtype,
#     463         "core_dims": input_core_dims,
#     464     },
#     465 )
#     467 # restore non-dim coord variables without the core dimension
#     468 # TODO: shouldn't apply_ufunc handle this?
#     469 for var in set(ds_broad._coord_names) - set(ds_broad._indexes) - set(ds_broad.dims):
#
# File /glade/u/apps/opt/conda/envs/npl-2025a/lib/python3.12/site-packages/xarray/core/computation.py:1258, in apply_ufunc(func, input_core_dims, output_core_dims, exclude_dims, vectorize, join, dataset_join, dataset_fill_value, keep_attrs, kwargs, dask, output_dtypes, output_sizes, meta, dask_gufunc_kwargs, on_missing_core_dim, *args)
#    1256 # feed datasets apply_variable_ufunc through apply_dataset_vfunc
#    1257 elif any(is_dict_like(a) for a in args):
# -> 1258     return apply_dataset_vfunc(
#    1259         variables_vfunc,
#    1260         *args,
#    1261         signature=signature,
#    1262         join=join,
#    1263         exclude_dims=exclude_dims,
#    1264         dataset_join=dataset_join,
#    1265         fill_value=dataset_fill_value,
#    1266         keep_attrs=keep_attrs,
#    1267         on_missing_core_dim=on_missing_core_dim,
#    1268     )
#    1269 # feed DataArray apply_variable_ufunc through apply_dataarray_vfunc
#    1270 elif any(isinstance(a, DataArray) for a in args):
#
# File /glade/u/apps/opt/conda/envs/npl-2025a/lib/python3.12/site-packages/xarray/core/computation.py:529, in apply_dataset_vfunc(func, signature, join, dataset_join, fill_value, exclude_dims, keep_attrs, on_missing_core_dim, *args)
#     524 list_of_coords, list_of_indexes = build_output_coords_and_indexes(
#     525     args, signature, exclude_dims, combine_attrs=keep_attrs
#     526 )
#     527 args = tuple(getattr(arg, "data_vars", arg) for arg in args)
# --> 529 result_vars = apply_dict_of_variables_vfunc(
#     530     func,
#     531     *args,
#     532     signature=signature,
#     533     join=dataset_join,
#     534     fill_value=fill_value,
#     535     on_missing_core_dim=on_missing_core_dim,
#     536 )
#     538 out: Dataset | tuple[Dataset, ...]
#     539 if signature.num_outputs > 1:
#
# File /glade/u/apps/opt/conda/envs/npl-2025a/lib/python3.12/site-packages/xarray/core/computation.py:453, in apply_dict_of_variables_vfunc(func, signature, join, fill_value, on_missing_core_dim, *args)
#     451 core_dim_present = _check_core_dims(signature, variable_args, name)
#     452 if core_dim_present is True:
# --> 453     result_vars[name] = func(*variable_args)
#     454 else:
#     455     if on_missing_core_dim == "raise":
#
# File /glade/u/apps/opt/conda/envs/npl-2025a/lib/python3.12/site-packages/xarray/core/computation.py:824, in apply_variable_ufunc(func, signature, exclude_dims, dask, output_dtypes, vectorize, keep_attrs, dask_gufunc_kwargs, *args)
#     819     if vectorize:
#     820         func = _vectorize(
#     821             func, signature, output_dtypes=output_dtypes, exclude_dims=exclude_dims
#     822         )
# --> 824 result_data = func(*input_data)
#     826 if signature.num_outputs == 1:
#     827     result_data = (result_data,)
#
# File /glade/u/apps/opt/conda/envs/npl-2025a/lib/python3.12/site-packages/flox/xarray.py:385, in xarray_reduce.<locals>.wrapper(array, func, skipna, core_dims, *by, **kwargs)
#     382         offset = array.min()
#     383         array = datetime_to_numeric(array, offset, datetime_unit="us")
# --> 385 result, *groups = groupby_reduce(array, *by, func=func, **kwargs)
#     387 # Transpose the new quantile dimension to the end. This is ugly.
#     388 # but new core dimensions are expected at the end :/
#     389 # but groupby_reduce inserts them at the beginning
#     390 if func in ["quantile", "nanquantile"]:
#
# File /glade/u/apps/opt/conda/envs/npl-2025a/lib/python3.12/site-packages/flox/core.py:2559, in groupby_reduce(array, func, expected_groups, sort, isbin, axis, fill_value, dtype, min_count, method, engine, reindex, finalize_kwargs, *by)
#    2556     return (result, groups)
#    2558 elif not has_dask:
# -> 2559     results = _reduce_blockwise(
#    2560         array,
#    2561         by_,
#    2562         agg,
#    2563         expected_groups=expected_,
#    2564         reindex=bool(reindex),
#    2565         sort=sort,
#    2566         **kwargs,
#    2567     )
#    2568     groups = (results["groups"],)
#    2569     result = results[agg.name]
#
# File /glade/u/apps/opt/conda/envs/npl-2025a/lib/python3.12/site-packages/flox/core.py:1431, in _reduce_blockwise(array, by, agg, axis, expected_groups, fill_value, engine, sort, reindex)
#    1428 assert agg.finalize_kwargs is not None
#    1429 finalize_kwargs_: tuple[dict[Any, Any], ...] = (agg.finalize_kwargs,) + ({},) + ({},)
# -> 1431 results = chunk_reduce(
#    1432     array,
#    1433     by,
#    1434     func=agg.numpy,
#    1435     axis=axis,
#    1436     expected_groups=expected_groups,
#    1437     # This fill_value should only apply to groups that only contain NaN observations
#    1438     # BUT there is funkiness when axis is a subset of all possible values
#    1439     # (see below)
#    1440     fill_value=agg.fill_value["numpy"],
#    1441     dtype=agg.dtype["numpy"],
#    1442     kwargs=finalize_kwargs_,
#    1443     engine=engine,
#    1444     sort=sort,
#    1445     reindex=reindex,
#    1446     user_dtype=agg.dtype["user"],
#    1447 )
#    1449 if _is_arg_reduction(agg):
#    1450     results["intermediates"][0] = np.unravel_index(results["intermediates"][0], array.shape)[-1]
#
# File /glade/u/apps/opt/conda/envs/npl-2025a/lib/python3.12/site-packages/flox/core.py:1075, in chunk_reduce(array, by, func, expected_groups, axis, fill_value, dtype, reindex, engine, kwargs, sort, user_dtype)
#    1073     result = reduction(group_idx, array, **kw_func)
#    1074 else:
# -> 1075     result = generic_aggregate(
#    1076         group_idx, array, axis=-1, engine=engine, func=reduction, **kw_func
#    1077     ).astype(dt, copy=False)
#    1078 if engine == "numbagg":
#    1079     result = _postprocess_numbagg(
#    1080         result,
#    1081         func=reduction,
#    (...)
#    1086         seen_groups=seen_groups,
#    1087     )
#
# File /glade/u/apps/opt/conda/envs/npl-2025a/lib/python3.12/site-packages/flox/aggregations.py:112, in generic_aggregate(group_idx, array, engine, func, axis, size, fill_value, dtype, **kwargs)
#     110 with warnings.catch_warnings():
#     111     warnings.filterwarnings("ignore", r"All-NaN (slice|axis) encountered")
# --> 112     result = method(
#     113         group_idx,
#     114         array,
#     115         axis=axis,
#     116         size=size,
#     117         fill_value=fill_value,
#     118         dtype=dtype,
#     119         **kwargs,
#     120     )
#     121 return result
#
# File /glade/u/apps/opt/conda/envs/npl-2025a/lib/python3.12/site-packages/numpy_groupies/aggregate_numpy.py:381, in aggregate(group_idx, a, func, size, fill_value, order, dtype, axis, **kwargs)
#     370 def aggregate(
#     371     group_idx,
#     372     a,
#    (...)
#     379     **kwargs,
#     380 ):
# --> 381     return _aggregate_base(
#     382         group_idx,
#     383         a,
#     384         size=size,
#     385         fill_value=fill_value,
#     386         order=order,
#     387         dtype=dtype,
#     388         func=func,
#     389         axis=axis,
#     390         _impl_dict=_impl_dict,
#     391         **kwargs,
#     392     )
#
# File /glade/u/apps/opt/conda/envs/npl-2025a/lib/python3.12/site-packages/numpy_groupies/aggregate_numpy.py:321, in _aggregate_base(group_idx, a, func, size, fill_value, order, dtype, axis, _impl_dict, is_pandas, **kwargs)
#     308 def _aggregate_base(
#     309     group_idx,
#     310     a,
#    (...)
#     319     **kwargs,
#     320 ):
# --> 321     iv = input_validation(group_idx, a, size=size, order=order, axis=axis, func=func)
#     322     group_idx, a, flat_size, ndim_idx, size, unravel_shape = iv
#     324     if group_idx.dtype == np.dtype("uint64"):
#     325         # Force conversion to signed int, to avoid issues with bincount etc later
#
# File /glade/u/apps/opt/conda/envs/npl-2025a/lib/python3.12/site-packages/numpy_groupies/utils.py:491, in input_validation(group_idx, a, size, order, axis, ravel_group_idx, check_bounds, func)
#     483         ndim_idx = ndim_a
#     484         size = (
#     485             orig_shape
#     486             if is_form_3 and not callable(func) and "cum" in func
#     487             else size
#     488         )
#     489         return (
#     490             group_idx.ravel(),
# --> 491             a.ravel(),
#     492             flat_size,
#     493             ndim_idx,
#     494             size,
#     495             unravel_shape,
#     496         )
#     498 if ndim_idx == 1:
#     499     if size is None:
#
# KeyboardInterrupt:

# %% [markdown]
# Calculating ozone column for [300hPa, 322.24hPa) and averaging it

# %%
ozone_300hpa_column = xr.dot(mod_deltap_filtered, xp_const*ozone_filtered, dims='lev')

# %%
ozone_du_300hpa_column = ozone_300hpa_column.copy() / DU_CONVERSION

ozone_du_300hpa_column = ozone_du_300hpa_column.where(ozone_du_300hpa_column != 0)

# %%
#ozone_du_300hpa_column = ozone_du_300hpa_column.sel(time=slice(start_date, end_date))
#ozone_du_300hpa_column = ozone_du_300hpa_column.groupby('time.month').mean('time')

# %% [markdown]
# Now calculating ozone column from 322.24hPa to ground level

# %%
ozone_part_column = xr.dot(pdeldry_monthly_mean, xp_const*ozone_monthly_mean, dims='lev')

# %%
ozone_du_column = ozone_part_column.copy() / DU_CONVERSION

# %% [markdown]
# Now calculate total tropospheric column ozone

# %%
ozone_du_300hpa_column = ozone_du_300hpa_column.fillna(0)
total_tco = ozone_du_column + ozone_du_300hpa_column

# %%
total_tco

# %% [markdown]
# Regridding and plotting

# %%
omi_mls_ds = xr.open_dataarray("/glade/u/home/mvoncyga/SOARS_2025/OMIMLS_300hpa_monthly_mean_2005_2024.nc")
omi_mls_ds = omi_mls_ds.rename({'latitude': 'lat', 'longitude': 'lon'})

# shifting lon to be 0-360
omi_mls_ds['lon'] = omi_mls_ds['lon'] % 360
omi_mls_ds = omi_mls_ds.sortby('lon')

# %%
#ozone_du_column_regridded = ozone_du_column.interp(coords=dict(lat=omi_mls_ds.lat, lon=omi_mls_ds.lon), method='linear')
regridder = xe.Regridder(total_tco, omi_mls_ds, 'bilinear', periodic=True)

# %%
cesm_regridded = regridder(total_tco)

# %%
cesm_regridded

# %%
month_list = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

for i in range(12):
    plt.figure(figsize=(10,8))
    ax = plt.axes(projection=ccrs.PlateCarree())

    # plotting data
    cesm_regridded[i].plot(vmin=5, vmax=40)
    
    ax.set_title("CESM $\mathregular{O_3}$ Concentration, "+ str(month_list[i]), fontsize=18)
    
    # add coastlines
    ax.add_feature(cfeature.COASTLINE, linestyle='--')

    # add lat lon grids
    gl = ax.gridlines(draw_labels=True, color='grey', alpha=0.8, linestyle='--')
    gl.xlabels_top = False
    gl.ylabels_right = False
    
    plt.show()

# %%
difference = cesm_regridded - omi_mls_ds

# %%
difference.mean(dim={'month','lat','lon'}, skipna=True)

# %%
alphabet = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l'] # for cycling through figures to create a gif

i = 0
for i in range(12):
    
    plt.figure(figsize=(10, 6))
    ax.set_facecolor('gray')
    ax = plt.axes(projection=ccrs.PlateCarree())
    difference[i].plot(ax=ax,transform=ccrs.PlateCarree(central_longitude=0), vmin = -20, vmax = 20, extend='both', cmap='bwr')
    ax.add_feature(cfeature.COASTLINE, linestyle='--')
    ax.set_global()

    # adding gridlines
    ax.gridlines(draw_labels=True, color='black', alpha=0.5, linestyle='--')
    ax.set_title("CESM - OMI/MLS Tropo O3 Difference: " + month_list[i] + ", 2005-2024", fontsize=14)
    
    formatted_mean = f"{difference[i].mean().data:.3f}"

    ax.text(0.10, -0.25, 'Mean: ' + str(formatted_mean) + ' DU', va='bottom', ha='center',
            rotation='horizontal', rotation_mode='anchor',
            transform=ax.transAxes, fontsize=12)
    

    #plt.savefig("figures/CESM_Diff-" + str(alphabet[i]))
    i+=1

    plt.show

# %%
import imageio
import os

def create_gif(image_folder, output_gif, duration):
    filenames = sorted([f for f in os.listdir(image_folder) if os.path.isfile(os.path.join(image_folder, f))])
    images = []
    for filename in filenames:
        if filename.startswith("CESM_Diff"):
            image_path = os.path.join(image_folder, filename)
            images.append(imageio.imread(image_path))
    imageio.mimsave(output_gif, images, duration=duration)

image_dir = '/glade/u/home/mvoncyga/SOARS_2025/figures/'

#create_gif(image_dir, "Difference_Plot.gif", duration=1000)
